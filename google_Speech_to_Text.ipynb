# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/100profes/blob/master/google_Speech_to_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Speech-to-Text en Colab

# %%
# Instalar la biblioteca de cliente de Google
# !pip install --upgrade google-cloud-speech

# %%
# Autenticación con el archivo JSON de Google Cloud
from google.colab import files
import os

# %%
# Subir el archivo JSON con las credenciales
print("Sube tu archivo JSON con las credenciales de Google Cloud:")
uploaded = files.upload()
# Out:
# Sube tu archivo JSON con las credenciales de Google Cloud:
#      <input type="file" id="files-2b49f0fd-e52f-4ac8-83b7-0f995c0a2bd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b49f0fd-e52f-4ac8-83b7-0f995c0a2bd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Establecer la variable de entorno para la autenticación
for filename in uploaded.keys():
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = filename
    print(f"Credenciales configuradas con: {filename}")
# Out:
# Credenciales configuradas con: inductive-voice-446100-c9-34b13acb99a9.json

# %%
# Importar las bibliotecas necesarias
from google.cloud import speech_v1p1beta1 as speech

# Función para transcribir audio usando Google Speech-to-Text
def transcribe_audio(file_path):
    """
    Transcribe un archivo de audio usando Google Speech-to-Text.
    """
    client = speech.SpeechClient()

    # Leer el contenido del archivo
    with open(file_path, "rb") as audio_file:
        content = audio_file.read()

    # Configuración de la solicitud
    audio = speech.RecognitionAudio(content=content)
    config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.MP3,  # Cambiar a MP3
      sample_rate_hertz=16000,  # Cambiar si la tasa de muestreo del audio es diferente
      language_code="es-ES",
      enable_speaker_diarization=True,
      diarization_speaker_count=2
)


    # Realizar la transcripción
    response = client.recognize(config=config, audio=audio)

    # Imprimir la transcripción
    for result in response.results:
        print("Transcripción:", result.alternatives[0].transcript)
        print("Palabras por hablante:", result.alternatives[0].words)

# Subir un archivo de audio para transcribir
print("Sube un archivo de audio (formato WAV recomendado):")
audio_file = files.upload()

# Transcribir el archivo subido
for audio_filename in audio_file.keys():
    print(f"Procesando el archivo: {audio_filename}")
    transcribe_audio(audio_filename)
# Out:
# Sube un archivo de audio (formato WAV recomendado):
#      <input type="file" id="files-1c0b8717-7da2-4360-84cd-07e1826df50e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c0b8717-7da2-4360-84cd-07e1826df50e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# !pip install pydub

# %%
from pydub import AudioSegment

def convert_mp3_to_wav(mp3_file, output_wav_file):
    audio = AudioSegment.from_file(mp3_file, format="mp3")
    audio.export(output_wav_file, format="wav")
    print(f"Archivo convertido: {output_wav_file}")

# Convertir el archivo subido
mp3_filename = "El Dr. House casi comete un error  #shorts.mp3"  # Cambia esto al nombre de tu archivo
wav_filename = "output.wav"
convert_mp3_to_wav(mp3_filename, wav_filename)
# Out:
# Archivo convertido: output.wav

# %%
from pydub import AudioSegment

def convert_to_mono(input_file, output_file):
    """
    Convierte un archivo de audio a mono.
    """
    audio = AudioSegment.from_file(input_file)
    mono_audio = audio.set_channels(1)  # Convertir a mono
    mono_audio.export(output_file, format="wav")
    print(f"Archivo convertido a mono: {output_file}")

# Convertir el archivo estéreo a mono
stereo_file = "output.wav"  # Archivo original estéreo
mono_file = "output_mono.wav"  # Nombre del archivo de salida en mono
convert_to_mono(stereo_file, mono_file)
# Out:
# Archivo convertido a mono: output_mono.wav

# %%
def transcribe_audio_as_play(file_path):
    """
    Transcribe un archivo de audio y formatea la salida como una obra de teatro.
    """
    client = speech.SpeechClient()

    # Leer el contenido del archivo
    with open(file_path, "rb") as audio_file:
        content = audio_file.read()

    # Configuración de la solicitud
    audio = speech.RecognitionAudio(content=content)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,  # Cambia si usas MP3
        sample_rate_hertz=44100,  # Cambiar a 44100 para que coincida con el archivo WAV
        language_code="es-ES",
        enable_speaker_diarization=True,  # Activar identificación de hablantes
        diarization_speaker_count=2  # Cambia según el número de hablantes
    )

    # Realizar la transcripción
    response = client.recognize(config=config, audio=audio)

    # Procesar los resultados
    formatted_script = []
    for result in response.results:
        alternative = result.alternatives[0]
        words = alternative.words
        current_speaker = None
        dialogue = []

        for word in words:
            # Identificar cambios de hablante
            if word.speaker_tag != current_speaker:
                # Si ya hay diálogo acumulado, lo añadimos al guion
                if dialogue:
                    formatted_script.append(
                        f"persona{current_speaker}: " + " ".join(dialogue)
                    )
                # Cambiamos al nuevo hablante
                current_speaker = word.speaker_tag
                dialogue = []
            # Añadimos la palabra al diálogo del hablante actual
            dialogue.append(word.word)

        # Añadir el último bloque de diálogo
        if dialogue:
            formatted_script.append(
                f"persona{current_speaker}: " + " ".join(dialogue)
            )

    # Imprimir el guion como una obra de teatro
    print("\n".join(formatted_script))

    # Devolver el guion para posibles usos posteriores
    return "\n".join(formatted_script)


# Procesar el archivo de audio convertido
formatted_script = transcribe_audio_as_play(mono_file)

# Guardar el guion en un archivo de texto
with open("obra_de_teatro.txt", "w", encoding="utf-8") as f:
    f.write(formatted_script)

print("Guion guardado como 'obra_de_teatro.txt'")
# Out:
# persona0: qué haces no pueden entrar aquí no toca a nuestro hijo ya le dijimos que hay millones de bacterias y microbios en ustedes morirá de sepsis creo que lo despertará otra vez House no puede hacer eso no se obtuvieron un centavo por cada vez que oigo eso cálmese que nos van a demandar pero si tengo razón salvaré su vida si me equivoco morirá no importa lo que haga deme la jeringa si no duele no sirve oiga ya es suficiente es verdad no lo dejaré hasta que me dé esa jeringa qué es eso en la muñeca una quemadura porque en la muñeca por qué no en la muñeca en la espalda el torso por todas partes pero en los antebrazos no excepto aquí tal vez una gota de gasolina ardiendo cayó en su muñeca un tornillo del vehículo
# ...

# %%
def transcribe_audio_as_play(file_path):
    """
    Transcribe un archivo de audio y formatea la salida como una obra de teatro,
    agrupando las palabras por hablante de manera más precisa.
    """
    client = speech.SpeechClient()

    # Leer el contenido del archivo
    with open(file_path, "rb") as audio_file:
        content = audio_file.read()

    # Configuración de la solicitud
    audio = speech.RecognitionAudio(content=content)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,  # Cambiar si usas MP3
        sample_rate_hertz=44100,  # Cambiar si la frecuencia es diferente
        language_code="es-ES",
        enable_speaker_diarization=True,  # Activar identificación de hablantes
        diarization_speaker_count=2  # Cambia según el número de hablantes
    )

    # Realizar la transcripción
    response = client.recognize(config=config, audio=audio)

    # Procesar los resultados
    dialogues = {}
    for result in response.results:
        alternative = result.alternatives[0]
        words = alternative.words
        for word in words:
            speaker_tag = word.speaker_tag
            if speaker_tag not in dialogues:
                dialogues[speaker_tag] = []  # Crear un nuevo hablante si no existe
            dialogues[speaker_tag].append(word.word)  # Añadir palabra al hablante

    # Formatear el resultado como obra de teatro
    formatted_script = []
    for speaker, words in dialogues.items():
        dialogue = " ".join(words)
        formatted_script.append(f"persona{speaker}: {dialogue}")

    # Imprimir el guion como una obra de teatro
    script = "\n".join(formatted_script)
    print(script)

    # Devolver el guion para posibles usos posteriores
    return script


# Procesar el archivo convertido a mono
formatted_script = transcribe_audio_as_play(mono_file)

# Guardar el guion en un archivo de texto
with open("text.txt", "w", encoding="utf-8") as f:
    f.write(formatted_script)

print("Guion guardado como 'text.txt'")
# Out:
# persona0: qué haces no pueden entrar aquí no toca a nuestro hijo ya le dijimos que hay millones de bacterias y microbios en ustedes morirá de sepsis creo que lo despertará otra vez House no puede hacer eso no se obtuvieron un centavo por cada vez que oigo eso cálmese que nos van a demandar pero si tengo razón salvaré su vida si me equivoco morirá no importa lo que haga deme la jeringa si no duele no sirve oiga ya es suficiente es verdad no lo dejaré hasta que me dé esa jeringa qué es eso en la muñeca una quemadura porque en la muñeca por qué no en la muñeca en la espalda el torso por todas partes pero en los antebrazos no excepto aquí tal vez una gota de gasolina ardiendo cayó en su muñeca un tornillo del vehículo
# ...

# %%
from google.cloud import speech_v1p1beta1 as speech

def transcribe_audio_gcs(gcs_uri):
    """
    Transcribe un archivo de audio grande almacenado en Google Cloud Storage usando Google Speech-to-Text.
    """
    client = speech.SpeechClient()

    # Configuración de la solicitud
    audio = speech.RecognitionAudio(uri=gcs_uri)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.MP3,  # Cambia si usas otro formato
        sample_rate_hertz=16000,  # Cambia si la tasa de muestreo del audio es diferente
        language_code="es-ES",
        enable_speaker_diarization=True,
        diarization_speaker_count=2
    )

    # Realizar la transcripción
    operation = client.long_running_recognize(config=config, audio=audio)

    print("Esperando resultados...")
    response = operation.result(timeout=300)  # Tiempo máximo de espera en segundos

    # Imprimir la transcripción
    for result in response.results:
        print("Transcripción:", result.alternatives[0].transcript)
        print("Palabras por hablante:", result.alternatives[0].words)

# URL del archivo en GCS
gcs_uri = "gs://tu-bucket/audio.mp3"  # Cambia esto por tu bucket y archivo

# Llamar a la función
transcribe_audio_gcs(gcs_uri)
